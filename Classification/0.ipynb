# %%
 # !pip install gdown
gdrive_link = "https://drive.google.com/uc?id=1UhMPzU-84KYH1-ujisJj08kb4Ji7gBLe"
# !gdown {gdrive_link}
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1UhMPzU-84KYH1-ujisJj08kb4Ji7gBLe
# From (redirected): https://drive.google.com/uc?id=1UhMPzU-84KYH1-ujisJj08kb4Ji7gBLe&confirm=t&uuid=400bca96-554a-441b-ba00-e8c5eb21dbc1
# To: /kaggle/working/data.2025.zip
# 100%|██████████████████████████████████████| 2.36G/2.36G [00:34<00:00, 68.2MB/s]

# %%
import zipfile
with zipfile.ZipFile("/kaggle/working/data.2025.zip", "r") as zip_ref:
    zip_ref.extractall("/kaggle/working/data.2025")

# %%
import torch
class Config:
    data_file = "/kaggle/input/cs231-cls/dataset.pkl"

# %%
import pickle as pkl
file_path = 'dataset.pkl'
with open(file_path , "wb") as f:
    pkl.dump({'word_data': data}, f, protocol=pkl.HIGHEST_PROTOCOL)

# %%
github_list = '''https://github.com/GwLewis369/Hand-written-digit-classification-data.git
https://github.com/gbaonr/CS114_handwritten_digits_data
https://github.com/adamwhite625/CS114_hand_written_digit.git
https://github.com/theRaven1312/CS114.P21
https://github.com/Khoiisme1905/CS114.git
https://github.com/ProjectHT1/machinelearning
https://github.com/Searching96/hand-written-digit.git
https://github.com/Salmon1605/CS114
https://github.com/anhtuann1224/hand_written_digit
https://github.com/NATuanAN/Hand_written_digit_classification_data.git
https://github.com/huapogba/may-hoc
https://github.com/hieutran890j2/CS114.git
https://github.com/votanhoang483/CS114.P21-Hand_written_digit_classification
https://github.com/DHPh/CS114_hand_written_digit/
https://github.com/thaituanUIT/ReminiScenceAI
https://github.com/anngyn/CS114-Hand-Written-Digit
https://github.com/lngphgthao/cs114-hand-written-digit-classification/tree/main/hand_written_digit
https://github.com/Toan02Ky-UIT/CS114
https://github.com/Lochke/CS114_Handwritten_Digit_Classification.git
https://github.com/NThong325/CS114/tree/cfd654a14dd471f5272387139d586ddcbf9cdf7e/hand_written_digit
https://github.com/toanlamdata/digit-recognition-group
https://github.com/Nohenshin/CS114.P21-2025-
https://github.com/hmcslearning/ML1142025
https://github.com/lngphgthao/cs114-hand-written-digit-classification
https://github.com/huapogba/may-hoc
https://github.com/NThong325/CS114/tree/main/hand_written_digit
https://github.com/23520276/Hand-written-digit-classification/
https://github.com/NThong325/CS114
'''

# %%
data_dir = "."
# %cd $data_dir
# !git config --global core.compression 0
# !rm -rf $data_dir/*
for i in github_list.split():
  # !echo $i
  # !git clone $i
  dir_name = !echo "$i" | sed -E 's|https://github.com/([^/]+)/([^/]+)(\.git)?|\1_\2|'
  dir_name = dir_name[0]
  # print(dir_name[0])
  # !git clone $i /tmp/$dir_name || rm -rf /tmp/$dir_name
  # !mv /tmp/$dir_name $data_dir/$dir_name
  # !echo $dir_name
  # !git clone $i
# Out:
# /kaggle/working
# Cloning into '/tmp/GwLewis369_Hand-written-digit-classification-data.git'...
# remote: Enumerating objects: 397, done.
# remote: Counting objects: 100% (397/397), done.
# remote: Compressing objects: 100% (382/382), done.
# remote: Total 397 (delta 5), reused 103 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (397/397), 23.05 MiB | 32.52 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Cloning into '/tmp/gbaonr_CS114_handwritten_digits_data'...
# remote: Enumerating objects: 837, done.
# remote: Counting objects: 100% (837/837), done.
# remote: Compressing objects: 100% (822/822), done.
# remote: Total 837 (delta 14), reused 721 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (837/837), 27.23 MiB | 39.17 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Cloning into '/tmp/adamwhite625_CS114_hand_written_digit.git'...
# remote: Enumerating objects: 350, done.
# remote: Counting objects: 100% (350/350), done.
# remote: Compressing objects: 100% (342/342), done.
# remote: Total 350 (delta 6), reused 110 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (350/350), 15.14 MiB | 25.93 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Cloning into '/tmp/theRaven1312_CS114.P21'...
# remote: Enumerating objects: 420, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 420 (delta 30), reused 43 (delta 24), pack-reused 370 (from 1)
# Receiving objects: 100% (420/420), 42.17 MiB | 23.05 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Updating files: 100% (354/354), done.
# Cloning into '/tmp/Khoiisme1905_CS114.git'...
# remote: Enumerating objects: 520, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 520 (delta 0), reused 102 (delta 0), pack-reused 417 (from 1)
# Receiving objects: 100% (520/520), 74.74 MiB | 41.84 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Cloning into '/tmp/ProjectHT1_machinelearning'...
# remote: Enumerating objects: 330, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 330 (delta 0), reused 118 (delta 0), pack-reused 212 (from 1)
# Receiving objects: 100% (330/330), 237.18 MiB | 41.94 MiB/s, done.
# Updating files: 100% (314/314), done.
# Cloning into '/tmp/Searching96_hand-written-digit.git'...
# remote: Enumerating objects: 311, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (309/309), done.
# remote: Total 311 (delta 1), reused 307 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (311/311), 8.95 MiB | 34.18 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Cloning into '/tmp/Salmon1605_CS114'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (258/258), done.
# remote: Compressing objects: 100% (256/256), done.
# remote: Total 258 (delta 0), reused 258 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (258/258), 16.80 MiB | 33.40 MiB/s, done.
# Cloning into '/tmp/anhtuann1224_hand_written_digit'...
# remote: Enumerating objects: 505, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 505 (delta 5), reused 3 (delta 3), pack-reused 498 (from 1)
# Receiving objects: 100% (505/505), 341.53 MiB | 39.45 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Updating files: 100% (407/407), done.
# Cloning into '/tmp/NATuanAN_Hand_written_digit_classification_data.git'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 136 (delta 1), reused 135 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 2.15 MiB | 22.74 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Cloning into '/tmp/huapogba_may-hoc'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 128 (delta 50), reused 56 (delta 15), pack-reused 1 (from 1)
# Receiving objects: 100% (128/128), 8.66 MiB | 31.44 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Cloning into '/tmp/hieutran890j2_CS114.git'...
# remote: Enumerating objects: 416, done.
# remote: Counting objects: 100% (416/416), done.
# remote: Compressing objects: 100% (411/411), done.
# remote: Total 416 (delta 2), reused 414 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (416/416), 12.75 MiB | 38.63 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Cloning into '/tmp/votanhoang483_CS114.P21-Hand_written_digit_classification'...
# remote: Enumerating objects: 663, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 663 (delta 0), reused 65 (delta 0), pack-reused 595 (from 1)
# Receiving objects: 100% (663/663), 194.05 MiB | 41.23 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Updating files: 100% (624/624), done.
# Cloning into '/tmp/DHPh_CS114_hand_written_digit'...
# remote: Enumerating objects: 480, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (254/254), done.
# remote: Total 480 (delta 9), reused 132 (delta 1), pack-reused 214 (from 1)
# Receiving objects: 100% (480/480), 83.99 MiB | 35.08 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# Cloning into '/tmp/thaituanUIT_ReminiScenceAI'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 208 (delta 25), reused 131 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (208/208), 2.70 MiB | 28.25 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Cloning into '/tmp/anngyn_CS114-Hand-Written-Digit'...
# remote: Enumerating objects: 241, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 241 (delta 0), reused 5 (delta 0), pack-reused 236 (from 1)
# Receiving objects: 100% (241/241), 104.54 MiB | 40.18 MiB/s, done.
# Cloning into '/tmp/lngphgthao_cs114-hand-written-digit-classification/tree/main/hand_written_digit'...
# fatal: repository 'https://github.com/lngphgthao/cs114-hand-written-digit-classification/tree/main/hand_written_digit/' not found
# mv: cannot stat '/tmp/lngphgthao_cs114-hand-written-digit-classification/tree/main/hand_written_digit': No such file or directory
# Cloning into '/tmp/Toan02Ky-UIT_CS114'...
# remote: Enumerating objects: 593, done.
# remote: Counting objects: 100% (350/350), done.
# remote: Compressing objects: 100% (347/347), done.
# remote: Total 593 (delta 12), reused 103 (delta 0), pack-reused 243 (from 2)
# Receiving objects: 100% (593/593), 164.41 MiB | 43.09 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Cloning into '/tmp/Lochke_CS114_Handwritten_Digit_Classification.git'...
# remote: Enumerating objects: 243, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 243 (delta 0), reused 0 (delta 0), pack-reused 240 (from 1)
# Receiving objects: 100% (243/243), 53.67 MiB | 38.78 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Cloning into '/tmp/NThong325_CS114/tree/cfd654a14dd471f5272387139d586ddcbf9cdf7e/hand_written_digit'...
# fatal: repository 'https://github.com/NThong325/CS114/tree/cfd654a14dd471f5272387139d586ddcbf9cdf7e/hand_written_digit/' not found
# mv: cannot stat '/tmp/NThong325_CS114/tree/cfd654a14dd471f5272387139d586ddcbf9cdf7e/hand_written_digit': No such file or directory
# Cloning into '/tmp/toanlamdata_digit-recognition-group'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 189 (delta 0), reused 72 (delta 0), pack-reused 110 (from 2)
# Receiving objects: 100% (189/189), 150.77 MiB | 41.25 MiB/s, done.
# Updating files: 100% (200/200), done.
# Cloning into '/tmp/Nohenshin_CS114.P21-2025-'...
# remote: Enumerating objects: 320, done.
# remote: Counting objects: 100% (320/320), done.
# remote: Compressing objects: 100% (316/316), done.
# remote: Total 320 (delta 1), reused 108 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (320/320), 1.24 MiB | 11.04 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Cloning into '/tmp/hmcslearning_ML1142025'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 120 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 27.03 MiB | 19.90 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# fatal: destination path '/tmp/lngphgthao_cs114-hand-written-digit-classification' already exists and is not an empty directory.
# mv: cannot stat '/tmp/lngphgthao_cs114-hand-written-digit-classification': No such file or directory
# Cloning into '/tmp/huapogba_may-hoc'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 128 (delta 50), reused 56 (delta 15), pack-reused 1 (from 1)
# Receiving objects: 100% (128/128), 8.66 MiB | 30.46 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Cloning into '/tmp/NThong325_CS114/tree/main/hand_written_digit'...
# fatal: repository 'https://github.com/NThong325/CS114/tree/main/hand_written_digit/' not found
# mv: cannot stat '/tmp/NThong325_CS114/tree/main/hand_written_digit': No such file or directory
# Cloning into '/tmp/23520276_Hand-written-digit-classification'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 122 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 19.71 MiB | 18.95 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# fatal: destination path '/tmp/NThong325_CS114' already exists and is not an empty directory.
# mv: cannot stat '/tmp/NThong325_CS114': No such file or directory

# %%
import os
import glob

import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision import transforms
from torchvision.transforms.v2 import ToTensor
import matplotlib.pyplot as plt
from torchvision.io import read_image
from torchvision.io import decode_image

# import path
a = glob.glob(f'{data_dir}/*/hand_written_digit/??52????')
print(len(a))
image_lists = []
for folder in a:
    files = glob.glob(f"{folder}/*")
    image_lists.extend(files)
# Out:
# 57

# %%
print(len(image_lists))
# Out:
# 6261

# %%
print(image_lists[0])
# Out:
# ./anhtuann1224_hand_written_digit/hand_written_digit/23520956/8_2_b.jpg

# %%
import os
import pickle as pkl
import torch
from torch.utils.data import Dataset
from PIL import Image
import numpy as np
from PIL import Image

data = {}
idx = 0

for path in image_lists:
    try:
        img = Image.open(path).convert("RGB")
        file = path.split("/")[-1]
        img = img.resize((64, 64))
        label = file.split("_")[0]
        if len(label)>1:
            print()
            continue

        label = int(label)
        data[idx] = [label, img]
        idx += 1
    except:
        print(f": path{path}")
# Out:
# : path./adamwhite625_CS114_hand_written_digit.git/hand_written_digit/23520667/README.md
#
#
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_blue3(1).HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_blue1(1).HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/7_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_blue1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/9_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/1_blue2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_red4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/8_red3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/5_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_red1.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/6_red2.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/3_blue4.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_blue3.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/0_red5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/4_blue5.HEIC
# : path./Khoiisme1905_CS114.git/hand_written_digit/22520077/2_red2.HEIC

# %%
print(len(data))
# Out:
# 6148

# %%
import pickle as pkl
file_path = 'dataset.pkl'
with open(file_path , "wb") as f:
    pkl.dump({'data': data}, f, protocol=pkl.HIGHEST_PROTOCOL)
