# %% [markdown]
# ## Classification

# %%
import torch
import torch.utils.data
import torch.utils.data as data_utils
import torchvision.transforms as transforms
import pickle as pkl
import pandas as pd
import torch
 
from tqdm import tqdm
from importlib import import_module
import shutil
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import logging
from torch.nn.utils.rnn import pad_sequence
import pickle as pkl
import cv2
import logging
import math
import functools
import torch.nn as nn
from torch.nn import init
import torch.optim as optim
import torch.nn.functional as F
from torch.nn import Parameter as P

class CustomDataset(data_utils.Dataset):
 
    def __init__(self):
  

        with open("C:/DOWLOAD/testKafka/data.pkl", "rb") as f:
            data = pkl.load(f)

        self.word_data = data["word_data"]
        self.idx_to_id = {i: w_id for i, w_id in enumerate(self.word_data.keys())}
        self.T = transforms.Compose(
            [transforms.Resize(64), transforms.Normalize(mean=[0.5], std=[0.5]),transforms.CenterCrop(64),]
        )
        
         
    def __len__(self):
        return len(self.word_data)

    def __getitem__(self, idx):
        item = {}
        w_id = self.idx_to_id[idx]

        # Get image and label
        lab, img = self.word_data[w_id]

        img = self.T(img)

        item["img"] = img.float()
        item["label"] = torch.tensor(lab)


        return item

dataset = CustomDataset()
import torchvision
dataloaders = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True, num_workers=0)

# %%
def imshow(inp, title=None):   
    inp = inp.numpy()
 
    inp = np.transpose(inp, (1, 2, 0))
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)

    if title is not None:
        plt.title(title)
    plt.axis('off')
    plt.show()


batch = next(iter(dataloaders))
inputs = batch["img"]
classes = batch["label"]
 
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[int(x) for x in classes])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25764\2988174177.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["label"] = torch.tensor(lab)

# %%
print(len(dataset))
# Out:
# 6349

# %%
import torchvision
dataloaders = dataloaders = torch.utils.data.DataLoader(dataset, batch_size=256, shuffle=True, num_workers=0)

       
def imshow(inp, title=None):
   
    inp = inp.numpy()
 
    inp = np.transpose(inp, (1, 2, 0))
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)

    if title is not None:
        plt.title(title)
    plt.axis('off')
    plt.show()


batch = next(iter(dataloaders))
inputs = batch["img"]
classes = batch["label"]
 
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[int(x) for x in classes])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25764\2560072210.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["label"] = torch.tensor(lab)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
device = "cuda"
model_ft = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 10)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
from tqdm import tqdm
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for batch in tqdm(dataloaders):
                    inputs = batch["img"].to(device)
                    labels = batch["label"].to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item()
     
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / len(dataloaders)
                

                print(f'{phase} Loss: {epoch_loss:.4f}')

                torch.save(model.state_dict(), best_model_params_path)
    return model

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=1)
# Out:
# Epoch 0/0
# ----------
#   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\ASUS\AppData\Local\Temp\ipykernel_25764\2988174177.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["label"] = torch.tensor(lab)
# 100%|██████████| 100/100 [00:04<00:00, 24.77it/s]
# train Loss: 1.3267

# %%
# import zipfile
# with zipfile.ZipFile("C:/DOWLOAD/testKafka/data.2025.zip", "r") as zip_ref:  
#     zip_ref.extractall("/kaggle/working/data.2025")

# %%
data_dir = "C:/DOWLOAD/testKafka/kaggle/working/data.2025"
file = os.listdir(data_dir)
print(file[0])
# Out:
# 000300afd862e8092248f343a27cdd75.jpg

# %%
class CustomDataset(data_utils.Dataset):
 
    def __init__(self):
  

        with open("C:/DOWLOAD/testKafka/data.pkl", "rb") as f:
            data = pkl.load(f)

        self.word_data = data["word_data"]
        self.idx_to_id = {i: w_id for i, w_id in enumerate(self.word_data.keys())}
        self.T = transforms.Compose(
            [
            transforms.RandomInvert()]
        )
         

    def __len__(self):
        return len(self.word_data)

    def __getitem__(self, idx):
        item = {}
        w_id = self.idx_to_id[idx]

        # Get image and label
        lab, img = self.word_data[w_id]

        # img = self.T(img)

        item["img"] = img.float()
        item["label"] = torch.tensor(lab)


        return item

dataset = CustomDataset()

# %%
import pickle as pkl
file_path = 'data.pkl'
with open(file_path , "wb") as f:
    pkl.dump({'word_data': dataset}, f, protocol=pkl.HIGHEST_PROTOCOL)

# %%
 
from PIL import Image
import torchvision.transforms as transforms

trans = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])
data = {}
idx = 0
data_dir = "C:/DOWLOAD/testKafka/kaggle/working/data.2025"
file = os.listdir(data_dir)
print(file[0])
for i in file:
    path = os.path.join(data_dir,i)
    try:
        image = Image.open(path).convert("RGB") 
        image = trans(image)
        data[idx] = [image]
        idx += 1
    except Exception as e:
        print(f"[Lỗi] {i}: {e}")
# for batch in tqdm(dataloaders):
#     inputs = batch["img"].to(device)
#     labels = batch["label"].to(device)
        
#     outputs = model(inputs)
#     _, preds = torch.max(outputs, 1)
# Out:
# 000300afd862e8092248f343a27cdd75.jpg
# [Lỗi] 004d39d8a48b484ba47ac058af0307d2.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\004d39d8a48b484ba47ac058af0307d2.HEIC'
# [Lỗi] 02c41345f52a4c87bcf29c0aed37a9ca  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\02c41345f52a4c87bcf29c0aed37a9ca  -.HEIC'
# [Lỗi] 057efebffefd1027b89c7a6f2ddd7ec0.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\057efebffefd1027b89c7a6f2ddd7ec0.HEIC'
# [Lỗi] 064e9f0be1e982a8f64ad6410df288c7.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\064e9f0be1e982a8f64ad6410df288c7.HEIC'
# [Lỗi] 0737c18223e6c8110ff767ee27841569.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\0737c18223e6c8110ff767ee27841569.HEIC'
# [Lỗi] 0805481419bb2b520b0f433f5cca66e1.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\0805481419bb2b520b0f433f5cca66e1.HEIC'
# [Lỗi] 0bc271063374f500276f8eeb627bf6b8.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\0bc271063374f500276f8eeb627bf6b8.HEIC'
# [Lỗi] 0c66d646ae2fcbf47295daa0fa6fd0f9.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\0c66d646ae2fcbf47295daa0fa6fd0f9.HEIC'
# [Lỗi] 0e308e4279faba22843c007c709d047f  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\0e308e4279faba22843c007c709d047f  -.HEIC'
# [Lỗi] 0edd5ff35ff1da9cee6db27375198ef0.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\0edd5ff35ff1da9cee6db27375198ef0.HEIC'
# [Lỗi] 1229d3dc11f8ed8b04c5c408a7cbde00.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\1229d3dc11f8ed8b04c5c408a7cbde00.HEIC'
# [Lỗi] 18b3189fa0aecab82ae817e8155a9844  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\18b3189fa0aecab82ae817e8155a9844  -.HEIC'
# [Lỗi] 1cba5631ee2db9e3362d0c0b8bf7a6ab.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\1cba5631ee2db9e3362d0c0b8bf7a6ab.HEIC'
# [Lỗi] 21151445fd63ff79440449974f17109d.jpg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\21151445fd63ff79440449974f17109d.jpg'
# [Lỗi] 240c99ed2f4fc115292ee39e630307d1  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\240c99ed2f4fc115292ee39e630307d1  -.HEIC'
# [Lỗi] 278a87ee160971f5ecf05a84b9feec6f.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\278a87ee160971f5ecf05a84b9feec6f.HEIC'
# [Lỗi] 285ad4e940ef9a0ccd936de1953f0239.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\285ad4e940ef9a0ccd936de1953f0239.HEIC'
# [Lỗi] 293f72922df347815dba619ea866db63.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\293f72922df347815dba619ea866db63.HEIC'
# [Lỗi] 2a96d698456e7c0918d136f7e3372847.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\2a96d698456e7c0918d136f7e3372847.HEIC'
# [Lỗi] 2c18ee0e7cea8354149df435532d74ae.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\2c18ee0e7cea8354149df435532d74ae.jpeg'
# [Lỗi] 2cc4b987bfe65eb3beda9870d3dd5571  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\2cc4b987bfe65eb3beda9870d3dd5571  -.HEIC'
# [Lỗi] 2e5ab66c892d882503a710aa97b7e15b.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\2e5ab66c892d882503a710aa97b7e15b.HEIC'
# [Lỗi] 313ec17e81da537717027fd5cb2e7d76.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\313ec17e81da537717027fd5cb2e7d76.HEIC'
# [Lỗi] 346c9d49d4f66bd42b90d9f034f240f6  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\346c9d49d4f66bd42b90d9f034f240f6  -.HEIC'
# [Lỗi] 34dff8cda52938e0ba5af071f116e88c.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\34dff8cda52938e0ba5af071f116e88c.HEIC'
# [Lỗi] 357162d6587502bc71c8c568d24fa894.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\357162d6587502bc71c8c568d24fa894.HEIC'
# [Lỗi] 379e725180d1877eee670939084c0361  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\379e725180d1877eee670939084c0361  -.HEIC'
# [Lỗi] 392cc53907e2fde1fd6faec6ddc898d0.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\392cc53907e2fde1fd6faec6ddc898d0.HEIC'
# [Lỗi] 3a816aa78f56749a0822d700ff560924.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\3a816aa78f56749a0822d700ff560924.jpeg'
# [Lỗi] 3b95f0841c21525f73d752193052fc9e.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\3b95f0841c21525f73d752193052fc9e.HEIC'
# [Lỗi] 3bce47afe5382ad9e32e1a007c623fea.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\3bce47afe5382ad9e32e1a007c623fea.HEIC'
# [Lỗi] 3bda949d7af8d430cd8b819e2cf70ce5.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\3bda949d7af8d430cd8b819e2cf70ce5.HEIC'
# [Lỗi] 3edc952b8034e0d91262887e6480a14d  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\3edc952b8034e0d91262887e6480a14d  -.HEIC'
# [Lỗi] 4056e13b8d7ffb1d3f69a64d3d742919  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\4056e13b8d7ffb1d3f69a64d3d742919  -.HEIC'
# [Lỗi] 4125170c9b33affe28532d84097fef4a  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\4125170c9b33affe28532d84097fef4a  -.HEIC'
# [Lỗi] 415b40d1bc1d46f4dd4010be6a8fc617  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\415b40d1bc1d46f4dd4010be6a8fc617  -.md'
# [Lỗi] 4246ea371a0a9096bb9b3d9048b7402d.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\4246ea371a0a9096bb9b3d9048b7402d.HEIC'
# [Lỗi] 44cdb9034171b588d1117a72b782022a.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\44cdb9034171b588d1117a72b782022a.HEIC'
# [Lỗi] 49b7fb99459b067e71249cedd07a1d99.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\49b7fb99459b067e71249cedd07a1d99.HEIC'
# [Lỗi] 4abc1b5dcf1be1de6503dc072e132fa0.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\4abc1b5dcf1be1de6503dc072e132fa0.jpeg'
# [Lỗi] 4d8a0d9e667cc03d9a1f4d5ea33497a8  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\4d8a0d9e667cc03d9a1f4d5ea33497a8  -.md'
# [Lỗi] 4e5b7067e21262aebfe20c6d33cafc91.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\4e5b7067e21262aebfe20c6d33cafc91.HEIC'
# [Lỗi] 4f9b940f50aca0456b4b2cde2efac1e6.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\4f9b940f50aca0456b4b2cde2efac1e6.HEIC'
# [Lỗi] 5090672d7a84d0adaf55641cec9bf5b3  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\5090672d7a84d0adaf55641cec9bf5b3  -.md'
# [Lỗi] 53e7d83b086a2ee826030a30443b73a7.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\53e7d83b086a2ee826030a30443b73a7.HEIC'
# [Lỗi] 54470885d0f378c9ea16c61a463729da.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\54470885d0f378c9ea16c61a463729da.HEIC'
# [Lỗi] 5a409fa2051d583419a4294ce7a3e94c.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\5a409fa2051d583419a4294ce7a3e94c.HEIC'
# [Lỗi] 609ae93438959bff10e7b96f8c24f779.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\609ae93438959bff10e7b96f8c24f779.HEIC'
# [Lỗi] 60e297f9b4795ffe3d287de602411e82.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\60e297f9b4795ffe3d287de602411e82.HEIC'
# [Lỗi] 614a8c12dd3771cedcabcdb3642ba95b.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\614a8c12dd3771cedcabcdb3642ba95b.HEIC'
# [Lỗi] 616172becdffb344ed0eaf6589f9b320  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\616172becdffb344ed0eaf6589f9b320  -.HEIC'
# [Lỗi] 6375b92d5a42019f1d133a59cdd8c24c.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\6375b92d5a42019f1d133a59cdd8c24c.HEIC'
# [Lỗi] 687f1d529d89358dab5f0c852cde3ca7.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\687f1d529d89358dab5f0c852cde3ca7.HEIC'
# [Lỗi] 68ad8a4c335540ddda059007530f6ec1.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\68ad8a4c335540ddda059007530f6ec1.HEIC'
# [Lỗi] 69c232bafe0d5cd79fb78a37eb5954b3.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\69c232bafe0d5cd79fb78a37eb5954b3.HEIC'
# [Lỗi] 6a5a47b6b7b85607580b24c4898095c0.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\6a5a47b6b7b85607580b24c4898095c0.HEIC'
# [Lỗi] 6d06d5647c50ba4830f4a16aab436611.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\6d06d5647c50ba4830f4a16aab436611.HEIC'
# [Lỗi] 70ebf0bec317006017a54d6c9172af45.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\70ebf0bec317006017a54d6c9172af45.jpeg'
# [Lỗi] 713398b3b545489e61fd7678ff6aafdf.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\713398b3b545489e61fd7678ff6aafdf.HEIC'
# [Lỗi] 72ae61add4d2fa9d1d3a70422d69a578.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\72ae61add4d2fa9d1d3a70422d69a578.HEIC'
# [Lỗi] 78f788851a15c5927a7d079cece219a3.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\78f788851a15c5927a7d079cece219a3.HEIC'
# [Lỗi] 79cc598c7c0fa1380a771bf724668662  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\79cc598c7c0fa1380a771bf724668662  -.HEIC'
# [Lỗi] 7a2a1096f943d2c0c939d6f6a6133750.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\7a2a1096f943d2c0c939d6f6a6133750.HEIC'
# [Lỗi] 7a975dd66107a7c2abf0e9978bef14a0.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\7a975dd66107a7c2abf0e9978bef14a0.HEIC'
# [Lỗi] 7b144c8aee2c11ad0a54433ccadb4a66.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\7b144c8aee2c11ad0a54433ccadb4a66.HEIC'
# [Lỗi] 7c70c7650c4d4827170ba054df8a7755.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\7c70c7650c4d4827170ba054df8a7755.HEIC'
# [Lỗi] 7ea219e24662f79b3beb31c8f6985d55  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\7ea219e24662f79b3beb31c8f6985d55  -.md'
# [Lỗi] 8177c77268d83ea964e8cb178188b52a.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\8177c77268d83ea964e8cb178188b52a.HEIC'
# [Lỗi] 81b728654dded4e1be0b8d918d647cb3.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\81b728654dded4e1be0b8d918d647cb3.HEIC'
# [Lỗi] 83177a8abb6ce6713485e253ed7eec55.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\83177a8abb6ce6713485e253ed7eec55.HEIC'
# [Lỗi] 831bb4c21d11e91b5bd9f79967156dca.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\831bb4c21d11e91b5bd9f79967156dca.HEIC'
# [Lỗi] 8325232c06f7d66a8fe192eea6016004.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\8325232c06f7d66a8fe192eea6016004.HEIC'
# [Lỗi] 8627553fc3ae84da85df6ee275ba7a3c  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\8627553fc3ae84da85df6ee275ba7a3c  -.HEIC'
# [Lỗi] 8c0832fa1ebf627c6e0714a4b6babcc1.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\8c0832fa1ebf627c6e0714a4b6babcc1.HEIC'
# [Lỗi] 8e4a38bd19c94970f342494bb01213d8  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\8e4a38bd19c94970f342494bb01213d8  -.HEIC'
# [Lỗi] 8eeee227b3f244e980b747387bc79bf2.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\8eeee227b3f244e980b747387bc79bf2.jpeg'
# [Lỗi] 8f00fcecffb85ab996447eae0cd15c52.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\8f00fcecffb85ab996447eae0cd15c52.HEIC'
# [Lỗi] 904f8bbb6668d45f51e425e0d606f4fe.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\904f8bbb6668d45f51e425e0d606f4fe.HEIC'
# [Lỗi] 95b3ee3016558d3c81de46dba3ef187f.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\95b3ee3016558d3c81de46dba3ef187f.HEIC'
# [Lỗi] 97397cc0b77329eae661764697469b2e.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\97397cc0b77329eae661764697469b2e.HEIC'
# [Lỗi] 974719e3b99c40fd0c51c120b7df92c6.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\974719e3b99c40fd0c51c120b7df92c6.HEIC'
# [Lỗi] 9a54372b22fc33b874f71a3e42ff2e0e.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9a54372b22fc33b874f71a3e42ff2e0e.HEIC'
# [Lỗi] 9aba5d9d100c31e76c2b9e1ef806e5d9.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9aba5d9d100c31e76c2b9e1ef806e5d9.HEIC'
# [Lỗi] 9b78ce3efdb35c807607f1d60e070094.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9b78ce3efdb35c807607f1d60e070094.HEIC'
# [Lỗi] 9d236ed1fb915adefa2bbf1ec38b3c00.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9d236ed1fb915adefa2bbf1ec38b3c00.HEIC'
# [Lỗi] 9d2cf96b868cc57eafeb7130fcd9edb4  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9d2cf96b868cc57eafeb7130fcd9edb4  -.HEIC'
# [Lỗi] 9e1f3378e66e8cd4c1f795d8e642fc60.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9e1f3378e66e8cd4c1f795d8e642fc60.HEIC'
# [Lỗi] 9e748b9617e26b90011f8d7c3f8a7eee.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9e748b9617e26b90011f8d7c3f8a7eee.jpeg'
# [Lỗi] 9ff224036fcd320556163e4b2feb813a.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\9ff224036fcd320556163e4b2feb813a.HEIC'
# [Lỗi] a008f795ae8498751f2e5feeb0b73387.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\a008f795ae8498751f2e5feeb0b73387.jpeg'
# [Lỗi] a0b35ada5bf03acd626f25b0f15fff3e.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\a0b35ada5bf03acd626f25b0f15fff3e.HEIC'
# [Lỗi] a0d770c40df773d5de1c5d04e485dff7.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\a0d770c40df773d5de1c5d04e485dff7.HEIC'
# [Lỗi] a22b9f14ea1e93e6a8771e71757679d7.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\a22b9f14ea1e93e6a8771e71757679d7.HEIC'
# [Lỗi] a551c30daf44700208d8ed24d70db855  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\a551c30daf44700208d8ed24d70db855  -.HEIC'
# [Lỗi] acb5f56a029c43112049f7c857148ba2.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\acb5f56a029c43112049f7c857148ba2.HEIC'
# [Lỗi] b099bfd1c41d1cc1bb35d846ca614747.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\b099bfd1c41d1cc1bb35d846ca614747.HEIC'
# [Lỗi] b24a5796b68c668268643ae25723f8d7.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\b24a5796b68c668268643ae25723f8d7.HEIC'
# [Lỗi] b287cb234bae7432b4f02b710fe97fcb.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\b287cb234bae7432b4f02b710fe97fcb.HEIC'
# [Lỗi] b87d645ad38f9bc1c03dc90470138d69  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\b87d645ad38f9bc1c03dc90470138d69  -.md'
# [Lỗi] b97120946046fd8a6febca02f8b9ac5b.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\b97120946046fd8a6febca02f8b9ac5b.HEIC'
# [Lỗi] ba7ce2058ad6af9b0664b0fba5a6596a.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\ba7ce2058ad6af9b0664b0fba5a6596a.HEIC'
# [Lỗi] bc137c1dc2466da50b14cc39a540ba64  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\bc137c1dc2466da50b14cc39a540ba64  -.HEIC'
# [Lỗi] bc6fcf20f608d914dfb039f863b34c58.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\bc6fcf20f608d914dfb039f863b34c58.HEIC'
# [Lỗi] bde1bdbc5fd356d9805d9eec375dcd92.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\bde1bdbc5fd356d9805d9eec375dcd92.HEIC'
# [Lỗi] be633c756666b255f89a23ae798d690d  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\be633c756666b255f89a23ae798d690d  -.HEIC'
# [Lỗi] bfa13efb7012f26ec808491f1b43d8eb  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\bfa13efb7012f26ec808491f1b43d8eb  -.HEIC'
# [Lỗi] c105bea8676a0e0a79286caf1bd86dc9.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\c105bea8676a0e0a79286caf1bd86dc9.HEIC'
# [Lỗi] c6ce9f623fc4dd820f40fad5f541c87e  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\c6ce9f623fc4dd820f40fad5f541c87e  -.HEIC'
# [Lỗi] cbc4dc5a5e02031c9970b4ffc5112be4  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\cbc4dc5a5e02031c9970b4ffc5112be4  -.md'
# [Lỗi] cc0be027be4388eb4bff3453e30c5e1b.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\cc0be027be4388eb4bff3453e30c5e1b.HEIC'
# [Lỗi] cd044b061bc5ed6a0d4984e85cc151c0.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\cd044b061bc5ed6a0d4984e85cc151c0.HEIC'
# [Lỗi] ce2388179ec73203a60d8efedd04e0f1.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\ce2388179ec73203a60d8efedd04e0f1.jpeg'
# [Lỗi] cede0cfc0f0d7af0029331ec34436d54.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\cede0cfc0f0d7af0029331ec34436d54.HEIC'
# [Lỗi] d01038195f9879d6118fd253d23e0470.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d01038195f9879d6118fd253d23e0470.HEIC'
# [Lỗi] d1491966c84a8371a5954a913468bf18.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d1491966c84a8371a5954a913468bf18.HEIC'
# [Lỗi] d32e098e3e66d9e979bf72b8dd18f894.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d32e098e3e66d9e979bf72b8dd18f894.HEIC'
# [Lỗi] d3d5000ba81d41e3db2659637beaed0b.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d3d5000ba81d41e3db2659637beaed0b.HEIC'
# [Lỗi] d434fe19e84d0adc3b2dd9022ba0214d.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d434fe19e84d0adc3b2dd9022ba0214d.HEIC'
# [Lỗi] d450d859bc776905a73c1c851c55524e  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d450d859bc776905a73c1c851c55524e  -.HEIC'
# [Lỗi] d48f421b5f1964b3590076e9a35db2fe.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d48f421b5f1964b3590076e9a35db2fe.HEIC'
# [Lỗi] d4b080c6ce4933f1199fad7f75e7d112.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d4b080c6ce4933f1199fad7f75e7d112.jpeg'
# [Lỗi] d4b5381a27ee385fcb5e5f1896edcc68  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d4b5381a27ee385fcb5e5f1896edcc68  -.HEIC'
# [Lỗi] d67a99873641d73fffd0498ce135dec9  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d67a99873641d73fffd0498ce135dec9  -.HEIC'
# [Lỗi] d79199e680f3053778b53532d4bc7fa4  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d79199e680f3053778b53532d4bc7fa4  -.md'
# [Lỗi] d9daaae75d68d855052f98739611640a.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\d9daaae75d68d855052f98739611640a.HEIC'
# [Lỗi] dacec8de1e92ae8a22657c3f4b7c6331.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\dacec8de1e92ae8a22657c3f4b7c6331.HEIC'
# [Lỗi] dbb7bae06ac5acffe3c8912675c4bc14  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\dbb7bae06ac5acffe3c8912675c4bc14  -.md'
# [Lỗi] dbd025557c0ff34f9099de9d421d8ebb  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\dbd025557c0ff34f9099de9d421d8ebb  -.HEIC'
# [Lỗi] dccf744fa61316959bcc58f70d3f9fd3.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\dccf744fa61316959bcc58f70d3f9fd3.HEIC'
# [Lỗi] e21dcb1cb0571a21a013b4232d1b6a13.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\e21dcb1cb0571a21a013b4232d1b6a13.jpeg'
# [Lỗi] e3aab03293995eaca8c3d24b9615dd8e  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\e3aab03293995eaca8c3d24b9615dd8e  -.HEIC'
# [Lỗi] e4f8ff42377664f204b76962bf774924  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\e4f8ff42377664f204b76962bf774924  -.md'
# [Lỗi] e63e2533582e3c0fed61a33f368af92e.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\e63e2533582e3c0fed61a33f368af92e.HEIC'
# [Lỗi] e978fb00a535e15e0ddec4f50089b8ac  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\e978fb00a535e15e0ddec4f50089b8ac  -.HEIC'
# [Lỗi] ea5baef8b76af40d854a8d330f96dff5.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\ea5baef8b76af40d854a8d330f96dff5.HEIC'
# [Lỗi] ea8496c521e0b12fb1f8e7f274071645.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\ea8496c521e0b12fb1f8e7f274071645.HEIC'
# [Lỗi] eb8c546148633071f33261f3d329a2d6.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\eb8c546148633071f33261f3d329a2d6.HEIC'
# [Lỗi] ec0c6e56d7d320f2041d35beb7f81225  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\ec0c6e56d7d320f2041d35beb7f81225  -.HEIC'
# [Lỗi] ee5f335ad27f7817568c36721924c8e9  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\ee5f335ad27f7817568c36721924c8e9  -.HEIC'
# [Lỗi] eeee89df765a939cc2ae56dae2fc15ed  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\eeee89df765a939cc2ae56dae2fc15ed  -.md'
# [Lỗi] f003259eee0f7319b6e91a80c46b5974.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f003259eee0f7319b6e91a80c46b5974.HEIC'
# [Lỗi] f1a32f97a09fd866097f1c483234dbe8  -.md: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f1a32f97a09fd866097f1c483234dbe8  -.md'
# [Lỗi] f204b661b1663aa3d3f11b458bdebfbd.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f204b661b1663aa3d3f11b458bdebfbd.HEIC'
# [Lỗi] f335ebd8f31b916c71ddd182bf2f2e40  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f335ebd8f31b916c71ddd182bf2f2e40  -.HEIC'
# [Lỗi] f36e0a9c5b7bab3d8a83c61f60144bf6.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f36e0a9c5b7bab3d8a83c61f60144bf6.HEIC'
# [Lỗi] f7679411e290bfd8dc90b3eadb57460a.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f7679411e290bfd8dc90b3eadb57460a.jpeg'
# [Lỗi] f8cd19f8c25a8a79d40e06ff706fd6a1.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f8cd19f8c25a8a79d40e06ff706fd6a1.HEIC'
# [Lỗi] f8d3dbfe59b434c9176772f0978ee01e.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f8d3dbfe59b434c9176772f0978ee01e.HEIC'
# [Lỗi] f986a68ead56729a5fd52fd338cc35a6.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f986a68ead56729a5fd52fd338cc35a6.HEIC'
# [Lỗi] f9af4cf10e5dfdf2b50e4ea133ad6262.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\f9af4cf10e5dfdf2b50e4ea133ad6262.HEIC'
# [Lỗi] faff9da17885d6589a9775ccdecb8b7d  -.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\faff9da17885d6589a9775ccdecb8b7d  -.HEIC'
# [Lỗi] fc972fff77ea8b755bb7de37f7c94046.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\fc972fff77ea8b755bb7de37f7c94046.HEIC'
# [Lỗi] fd50b14dd3d3d0a482a4efc55d525298.HEIC: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\fd50b14dd3d3d0a482a4efc55d525298.HEIC'
# [Lỗi] ffd4f9df7163f55474a0182265c8d810.jpeg: cannot identify image file 'C:\\DOWLOAD\\testKafka\\kaggle\\working\\data.2025\\ffd4f9df7163f55474a0182265c8d810.jpeg'

# %% [markdown]
# ## Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso

# %%
df = pd.read_csv('C:/DOWLOAD/testKafka/wecode.data/annonimized.csv')
df.head()

# %%
# Load điểm
df_ck = pd.read_csv('C:/DOWLOAD/testKafka/wecode.data/ck-public.csv')
df_qt = pd.read_csv('C:/DOWLOAD/testKafka/wecode.data/qt-public.csv')
df_th = pd.read_csv('C:/DOWLOAD/testKafka/wecode.data/th-public.csv')

# Gộp điểm
df_scores = df_ck.merge(df_qt, on='hash', how='outer', suffixes=('_CK', '_QT'))
df_scores = df_scores.merge(df_th, on='hash', how='outer').rename(columns={'CK': 'CK', 'QT': 'QT', 'TH': 'TH'})

# Gộp vào wecode
df['hash'] = df["concat('it001', username)"]
df_full = df.merge(df_scores, on='hash', how='inner')  # chỉ lấy sinh viên có điểm thật

# %%
df_full.head(n = 50)

# %%
# Kiểm tra dữ liệu có trùng lặp
df_full.duplicated().any()

# %%
# Kích thước dataset
row, column = df.shape
print(f"Row: {row}, Column: {column}")

# %%
# Kích thước dataset
row, column = df_full.shape
print(f"Row: {row}, Column: {column}")

# %%
df_full.isnull().sum()

# %%
df_full = df_full.dropna(subset=['CK',"diemqt","TH"])

# %%
df_full.isnull().sum()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["concat('it001',`assignment_id`)"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["concat('it001',`problem_id`)"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["concat('it001', username)"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["is_final"],bins=2)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["status"],bins=4)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["pre_score"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["coefficient"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["concat('it001',`language_id`)"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["CK"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["diemqt"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_full["TH"],bins=10)
plt.title("Histogram of Item_Weight")
plt.xlabel("Item_Weight")
plt.ylabel("Frequency")

# %%
# Bước 1: tạo 3 cột đánh dấu trạng thái từng dòng
df_full['submit_late'] = (df_full['pre_score'] == 0).astype(int)
df_full['submit_semi_late'] = ((df_full['pre_score'] > 0) & (df_full['pre_score'] < 10000)).astype(int)
df_full['submit_ontime'] = (df_full['pre_score'] == 10000).astype(int)

# Bước 2: groupby theo sinh viên
df_submit_stats = df_full.groupby('hash').agg(
    num_submit_late = ('submit_late', 'sum'),
    num_submit_semi_late = ('submit_semi_late', 'sum'),
    num_submit_ontime = ('submit_ontime', 'sum')
).reset_index()

# %%
df_full.drop(columns=['late_submit'], inplace=True)

# %%
df_submit_stats

# %%
df_full.head(n = 500)

# %%
df_full['last_weighted_score'] = df_full['is_final'].astype(int) * (df_full['pre_score'] * df_full['coefficient'] / 10000)

# %%
df_full.head(n = 500)

# %%
df_full['is_error'] = (df_full['status'] != 'SCORE').astype(int)
df_full.head()

# %%
df_full['is_success_submit'] = ((df_full['is_final'] == 1) & (df_full['coefficient'] == 100)).astype(int)
df_full.head()

# %%
df_full['created_at'] = pd.to_datetime(df_full['created_at'], format='%m-%d %H:%M:%S', errors='coerce')
df_full.head(n=5)

# %%
# Bước 1: chuẩn hóa thời gian
df_full['created_at'] = pd.to_datetime(df_full['created_at'], format='%m-%d %H:%M:%S', errors='coerce')

# Bước 2: tìm thời điểm bắt đầu làm từng bài (min theo hash + problem)
df_start_time = df_full.groupby(['hash', "concat('it001',`problem_id`)"])['created_at'].min().reset_index()
df_start_time = df_start_time.rename(columns={'created_at': 'assignment_start_time'})

# Bước 3: merge ngược lại để mỗi dòng biết lúc nào bắt đầu assignment đó
df_full = df_full.merge(df_start_time, on=['hash', "concat('it001',`problem_id`)"], how='left')

# Bước 4: tính thời gian làm bài tính đến dòng hiện tại
df_full['time_spent_hours'] = (df_full['created_at'] - df_full['assignment_start_time']).dt.total_seconds() / 3600
df_full.head()

# %%
# Lọc những dòng là lần final nộp cho mỗi assignment
df_final_submits = df_full[df_full['is_final'] == 1].copy()

# Lấy giờ nộp final
df_final_submits['final_hour'] = df_final_submits['created_at'].dt.hour

# Tạo bảng ánh xạ (hash, assignment) → giờ nộp final
df_final_hour_map = df_final_submits[[
    'hash',
    "concat('it001',`problem_id`)",
    'final_hour'
]]

# %%
df_full = df_full.merge(
    df_final_hour_map,
    on=['hash', "concat('it001',`problem_id`)"],
    how='left'
)

# %%
df_full.head(n= 10)

# %%
df_full['submit_weekday'] = df_full['created_at'].dt.dayofweek
df_full.head(n = 5)

# %%
df_full['created_at'] = pd.to_datetime(df_full['created_at'], errors='coerce')
df_full['submit_date'] = df_full['created_at'].dt.date

# Tính khoảng thời gian mỗi ngày mỗi sinh viên
df_daily_time = df_full.groupby(['hash', 'submit_date'])['created_at'].agg(['min', 'max']).reset_index()
df_daily_time['hours_spent'] = (df_daily_time['max'] - df_daily_time['min']).dt.total_seconds() / 3600
df_avg_time = df_daily_time.groupby('hash')['hours_spent'].mean().reset_index()
df_avg_time.columns = ['hash', 'avg_hours_per_day']

# %%
df_full = df_full.merge(df_avg_time, on='hash', how='left')
df_full.head(n=5)

# %%
df_full.info()

# %%
df_working_days = df_full.groupby('hash')['submit_date'].nunique().reset_index()
df_working_days.columns = ['hash', 'total_working_days']
df_full = df_full.merge(df_working_days, on='hash', how='left')
df_full.head()

# %%
df_full.info()

# %%
df_features = df_scores.copy()
df_features.head()

# %%
valid_hashes = df_scores['hash'].unique()
df_filtered = df_full[df_full['hash'].isin(valid_hashes)]
df_submit_counts = df_filtered.groupby('hash').size().reset_index(name='num_total_submissions')
df_features = df_features.merge(df_submit_counts, on='hash', how='left')
df_features.head()

# %%
df_success_submit_count = df_full.groupby('hash')['is_success_submit'].sum().reset_index()
df_success_submit_count.columns = ['hash', 'num_success_submit']
df_features = df_features.merge(df_success_submit_count, on='hash', how='left')

# %%
df_features.head(n = 10)

# %%
df_submit_types = df_full.groupby('hash')[[
    'submit_late',
    'submit_semi_late',
    'submit_ontime'
]].sum().reset_index()

# (Optional) Đổi tên cho rõ ràng
df_submit_types = df_submit_types.rename(columns={
    'submit_late': 'num_submit_late',
    'submit_semi_late': 'num_submit_semi_late',
    'submit_ontime': 'num_submit_ontime'
})
df_features = df_features.merge(df_submit_types, on='hash', how='left')
df_features.head()

# %%
df_avg_last_score = df_full.groupby('hash')['last_weighted_score'].mean().reset_index()
df_avg_last_score.columns = ['hash', 'avg_last_weighted_score']
df_features = df_features.merge(df_avg_last_score, on='hash', how='left')
df_features.head()

# %%
df_error_count = df_full.groupby('hash')['is_error'].sum().reset_index()
df_error_count.columns = ['hash', 'num_error_submissions']
df_features = df_features.merge(df_error_count, on='hash', how='left')
df_features.head()

# %%
df_problem_time = df_full.groupby(['hash', "concat('it001',`problem_id`)"])['created_at'].agg(['min', 'max']).reset_index()
df_problem_time['total_time_hours'] = (df_problem_time['max'] - df_problem_time['min']).dt.total_seconds() / 3600
df_avg_time_per_problem = df_problem_time.groupby('hash')['total_time_hours'].mean().reset_index()
df_avg_time_per_problem.columns = ['hash', 'avg_time_per_problem']
df_features = df_features.merge(df_avg_time_per_problem, on='hash', how='left')
df_features.head()

# %%
def hour_to_period_encoded(hour):
    if pd.isna(hour): return -1  # Không rõ
    if 7 <= hour < 12: return 0   # Đêm
    elif 12 <= hour < 19: return 1  # Sáng
    elif 19 <= hour < 23: return 2  # Chiều
    else: return 3  # Tối
# B1: Gán trực tiếp final_period_encoded từ final_hour
df_final_period = df_full[df_full['final_hour'].notna()].copy()
df_final_period['final_period_encoded'] = df_final_period['final_hour'].apply(hour_to_period_encoded)

# B2: Lấy mode theo hash
def mode_or_first(series):
    modes = series.mode()
    return modes.iloc[0] if not modes.empty else -1  # fallback là "Không rõ"

df_final_encoded_mode = df_final_period.groupby('hash')['final_period_encoded'].apply(mode_or_first).reset_index()

# B3: Gộp vào df_features
df_features = df_features.merge(df_final_encoded_mode, on='hash', how='left')

# %%
df_features.head()

# %%
df_full['submit_weekday'] = df_full['created_at'].dt.dayofweek  # 0 = Monday, 6 = Sunday
df_weekday_counts = df_full.groupby(['hash', 'submit_weekday']).size().unstack(fill_value=0).reset_index()
df_weekday_counts.columns = ['hash'] + [f'num_submit_weekday_{i}' for i in range(7)]
# Hoặc đặt tên thân thiện:
weekday_map = {
    0: 'mon', 1: 'tue', 2: 'wed', 3: 'thu', 4: 'fri', 5: 'sat', 6: 'sun'
}
df_weekday_counts.rename(columns={i: f'num_submit_{name}' for i, name in weekday_map.items()}, inplace=True)
df_features = df_features.merge(df_weekday_counts, on='hash', how='left')
df_features.head()

# %%
df_features = df_features.merge(df_avg_time, on='hash', how='left')
df_features.head()

# %%
df_features.info()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chuyển các biến mục tiêu về số nếu chưa
df_corr = df_features.copy()
df_corr['CK'] = pd.to_numeric(df_corr['CK'], errors='coerce')
df_corr['diemqt'] = pd.to_numeric(df_corr['diemqt'], errors='coerce')
df_corr['TH'] = pd.to_numeric(df_corr['TH'], errors='coerce')

# Tính ma trận tương quan
target_cols = ['CK', 'diemqt', 'TH']
for target in target_cols:
    plt.figure(figsize=(12, 6))
    corr = df_corr.corr(numeric_only=True)[[target]].sort_values(by=target, ascending=False)
    sns.heatmap(corr, annot=True, cmap='coolwarm')
    plt.title(f'Tương quan giữa các đặc trưng và {target}')
    plt.show()

# %%
df_f_raw = df_features.copy()

# %%
df_features = df_f_raw

# %%
df_features = df_features.dropna()

# %%
cols_to_scale = [
    'num_total_submissions', 'num_success_submit',
    'num_submit_late', 'num_submit_semi_late', 'num_submit_ontime',
    'avg_last_weighted_score', 'num_error_submissions',
    'avg_time_per_problem', 'avg_hours_per_day',
    'num_submit_weekday_0', 'num_submit_weekday_1', 'num_submit_weekday_2',
    'num_submit_weekday_3', 'num_submit_weekday_4', 'num_submit_weekday_5',
    'num_submit_weekday_6'
]

# %%
df_features.head()

# %%
print("Giá trị bị mất sau khi làm sạch:")
print(df_features[['CK', 'diemqt', 'TH']].isna().sum())

print("\nMột số giá trị gốc gây lỗi có thể là:")
for col in ['CK', 'diemqt', 'TH']:
    raw_vals = df_f_raw[col].unique()
    print(f"\n{col}:", [v for v in raw_vals if isinstance(v, str) and not re.match(r'^\s*\d+(\.\d+)?\s*$', v)])

# %%
import re

def clean_score_column(col):
    return (
        df_features[col]
        .astype(str)
        .apply(lambda x: re.sub(r'[^\d\.]', '', x))  # giữ lại số & dấu chấm
        .replace('', np.nan)
        .astype(float)
    )

for col in ['CK', 'diemqt', 'TH']:
    df_features[col] = clean_score_column(col)

# %%
df_features['diemqt'] = df_features['diemqt'].replace('\xa0', 0).astype(float)
df_features['TH'] = df_features['TH'].replace('\xa0', 0).astype(float)

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1. Xử lý dữ liệu
df = df_features.dropna()

X = df.drop(columns=['hash', 'CK', 'diemqt', 'TH'])
y = df['TH']  # hoặc 'diemqt' hoặc 'TH'

# 2. Chuẩn hóa dữ liệu số
X_cat = X[['final_period_encoded']]
X_num = X.drop(columns=['final_period_encoded'])

scaler = StandardScaler()
X_num_scaled = scaler.fit_transform(X_num)

X_processed = np.hstack([X_num_scaled, X_cat.values])

# 3. Chia dữ liệu train/test
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42
)

# 4. Khởi tạo và huấn luyện LightGBM
model = lgb.LGBMRegressor(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=-1,
    random_state=42
)
model.fit(X_train, y_train)

# 5. Dự đoán và đánh giá
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"✅ MAE: {mae:.4f}")
print(f"✅ RMSE: {rmse:.4f}")
print(f"✅ R² Score: {r2:.4f}")

# %%
# Tìm tất cả cột chứa dạng object (string)
obj_cols = df_features.select_dtypes(include='object').columns

# In ra những cột có ít nhất một giá trị chứa '\xa0'
for col in obj_cols:
    if df_features[col].astype(str).str.contains('\xa0').any():
        print(f"Cột '{col}' có chứa ký tự '\\xa0'")

# %%
# In tất cả các giá trị duy nhất trong diemqt chứa '\xa0'
print("Các giá trị lỗi trong 'diemqt':")
print(df_features.loc[df_features['diemqt'].astype(str).str.contains('\xa0'), 'diemqt'].unique())

print("\nCác giá trị lỗi trong 'TH':")
print(df_features.loc[df_features['TH'].astype(str).str.contains('\xa0'), 'TH'].unique())
